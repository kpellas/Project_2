# %%
# Load libraries
import pandas as pd
import pymongo
import json

# %%
# Create MongoDB and Python connection
client = pymongo.MongoClient("mongodb://localhost:27017")

# %%
#Read .CSV file
basic_sanitation = pd.read_csv("./data/basic_sanitation.csv")

basic_sanitation.head()
# Out:
#    Unnamed: 0         Country  \
# 0           0     Afghanistan
# 1           1         Albania
# 2           2         Algeria
# 3           3  American Samoa
# 4           4         Andorra
#
#                                            Indicator        2018
# 0  People using at least basic sanitation service...   47.390662
# 1  People using at least basic sanitation service...   98.973644
# 2  People using at least basic sanitation service...   86.303092
# 3  People using at least basic sanitation service...   54.454760
# 4  People using at least basic sanitation service...  100.000001

# %%
basic_sanitation_data = access_electricity.to_dict(orient = "records")

# %%
basic_sanitation_data
# Out:
# [{'Unnamed: 0': 0,
#   'Country': 'Afghanistan',
#   'Indicator': 'Access to electricity (% of population)',
#   '2018': 98.7156219482422},
#  {'Unnamed: 0': 1,
#   'Country': 'Albania',
#   'Indicator': 'Access to electricity (% of population)',
#   '2018': 100.0},
#  {'Unnamed: 0': 2,
#   'Country': 'Algeria',
#   'Indicator': 'Access to electricity (% of population)',
#   '2018': 99.6419219970703},
#  {'Unnamed: 0': 3,
#   'Country': 'American Samoa',
#   'Indicator': 'Access to electricity (% of population)',
#   '2018': nan},
#  {'Unnamed: 0': 4,
#   'Country': 'Andorra',
#   'Indicator': 'Access to electricity (% of population)',
#   '2018': 100.0},
#  {'Unnamed: 0': 5,
#   'Country': 'Angola',
#   'Indicator': 'Access to electricity (% of population)',
#   '2018': 45.29},
#  {'Unnamed: 0': 6,
#   'Country': 'Antigua and Barbuda',
#   'Indicator': 'Access to electricity (% of population)',
#   '2018': 99.9997253417969},
#  {'Unnamed: 0': 7,
#   'Country': 'Argentina',
# ...

# %%
db = client["WDI_db"]

# %%
print(db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'WDI_db')

# %%
db.Basic_Sanitation.insert_many(basic_sanitation_data)
